# %%
import sys
sys.path.insert(0, './py_torch_trpo')
from baselines.common import set_global_seeds, tf_util as U
import gym
import roboschool
import numpy as np
import random
from expert import *
import matplotlib.pyplot as plt
import time
import pandas as pd
import seaborn as sns
from gym import spaces
from base_line_model.TRPO_agent import TRPO_agent_new
from base_line_model.mlp import MlpPolicy_new
from baselines import logger

plt.style.use('seaborn-white')
sns.set(context = "paper", font = "monospace", font_scale=2)

seed = 1
logger.configure()
U.make_session(num_cpu=16).__enter__()
set_global_seeds(seed)
# Out:
# Logging to /tmp/openai-2018-06-10-20-00-48-776783

# %%
class action_space(object):
    def __init__(self, env):
        self.env = env
        self.high = np.array([ 1,  1,  1,  1,  1])
        self.low = -np.array([ 1,  1,  1,  1,  1])
        self.shape = env.observation_space.shape
    
    def sample(self):
    
        return self.env.observation_space.sample()
        
        
class adversial_env(object):
    def __init__(self):
        # parameter
        self.env = gym.make("RoboschoolInvertedPendulum-v1")
        self.env.seed(0)
        self.ratio = 2
        self.threshold = np.array([ 0,  0,  0,  0.00789366,  0])
        self.max_turn = 1000
        self.combine_ratio = 0.05
        
        self.action_space = spaces.Box(low=-1, high=1, shape=(self.env.observation_space.shape[0],))
        self.observation_space = self.env.observation_space
        self.agent = SmallReactivePolicy(self.env.observation_space, self.env.action_space) # declare sample trained agent
        self.obsr = 0
        self.epi_num = 0
        self.total_score = 0
        self.first = True
        self.run_avg = 0
        self.rvg_list = []
        self.score_list = []
        self.epi_list = []
        self.env.metadata
    
    # define reward function
    def reward(self, st):
        return np.abs(st[3])-0.08 #np.abs(st[3])+0.2*np.abs(st[1])-0.08#
    
    def step(self, a):
        self.epi_num = self.epi_num + 1
        
        obs = np.clip(a,-1,1)*self.threshold*self.ratio + self.obsr
        ac = self.agent.act(obs)
        self.obsr, r, done, _ = self.env.step(ac)
        #print( np.clip(a,-1,1),np.clip(a,-1,1)*self.ratio)
        
        if self.epi_num >= self.max_turn:
            done = True
        
        if self.first and done: ###################################
            self.first = False
            self.run_avg = self.total_score
            self.score_list = [self.total_score]
            self.epi_list = [self.epi_num]
            print(self.run_avg, self.score_list, self.epi_list)
            
        
        final_r = self.reward(self.obsr)
        if done and self.epi_num < self.max_turn:
            final_r = 0 # terminal cost 
        
        self.total_score += final_r
        return self.obsr, final_r, done, 0
        
        
    def seed(self, a):
        pass
    
    def reset(self):
        self.obsr = self.env.reset()
        #print(self.total_score)
        self.run_avg = (self.combine_ratio*self.total_score) + (1-self.combine_ratio)*self.run_avg
        #print(self.run_avg)
        #print(self.epi_num)
        
        if not self.first: #########################################
            self.rvg_list.append(self.run_avg)
            self.score_list.append(self.total_score)
            self.epi_list.append(self.epi_num)
        
        self.epi_num = 0
        self.total_score = 0
        return self.obsr
    
    def result_plot(self):
        fon_size = 19
        x = list(range(0, len(self.score_list[1:])))
        fig=plt.figure(figsize=(18, 4), dpi= 80, facecolor='w', edgecolor='k')
        plt.subplot(1,2,1)
        plt.scatter(x,self.score_list[1:], s=5)
        plt.xlabel('episodes',fontsize=fon_size)
        plt.ylabel('Adversary reward',fontsize=fon_size)
        plt.ylim([-80,-15])
        #plt.subplot(1,3,2)
        #plt.plot(self.rvg_list[1:])
        #plt.xlabel('episodes')
        #plt.ylabel('running average reward')
        plt.subplot(1,2,2)
        x = list(range(0, len(self.epi_list)))
        plt.scatter(x,self.epi_list, s=5)
        plt.xlabel('episodes',fontsize=fon_size)
        plt.ylabel('time steps',fontsize=fon_size)
        plt.ylim([0,1200])
        fig.savefig('foo.pdf', bbox_inches='tight')
        plt.show()

# %% [markdown]
# # define an adversary(new agent)

# %%
env2 = adversial_env()
class pargm(object):
    def __init__(self):
        self.timesteps_per_batch = 50000 # what to train on
        self.max_kl = 0.01
        self.cg_iters = 10
        self.gamma = 0.995
        self.lam =  0.97# advantage estimation
        self.entcoeff=0.0
        self.cg_damping=0.1
        self.vf_stepsize=1e-3
        self.vf_iters =5
        self.max_timesteps = 1e8
        self.max_episodes=0
        self.max_iters=0  # time constraint
        self.max_epi_avg = 1001
        self.callback=None


def policy_fn(name, ob_space, ac_space):
        return MlpPolicy_new(name=name, ob_space=ob_space, ac_space=ac_space,
            hid_size=128, num_hid_layers=2)
    
parg = pargm()
agn = TRPO_agent_new('pi1', env2, policy_fn, parg)
#agn.restore('adversary')
# Out:
# [2018-06-10 20:00:49,512] Making new env: RoboschoolInvertedPendulum-v1
# Init param sum 1.91204

# %% [markdown]
# # Agent training

# %%
agn.learn()
# Out:
# ********** Iteration 0 ************
# sampling
# -75.3542930053 [-75.35429300529475] [1000]
# done in 96.109 seconds
# computegrad
# done in 0.599 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00164          0
#          1   0.000681      0.008
#          2   0.000164     0.0132
#          3   3.54e-05     0.0214
#          4   5.16e-06     0.0449
#          5   3.58e-06     0.0461
#          6   2.76e-06     0.0463
#          7   4.41e-07     0.0482
#          8    2.5e-08     0.0483
#          9   2.91e-08     0.0484
#         10   4.47e-10     0.0484
# done in 1.375 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 18.641 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -75        |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 50         |
# | TimeElapsed     | 118        |
# | TimestepsSoFar  | 50000      |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | -0.0921    |
# | meankl          | 0.00697818 |
# | optimgain       | 0.00432073 |
# | surrgain        | 0.00432073 |
# --------------------------------
# ********** Iteration 1 ************
# sampling
# done in 95.148 seconds
# computegrad
# done in 0.296 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00107          0
#          1   0.000278    0.00467
#          2   7.56e-05      0.014
#          3   1.79e-05     0.0165
#          4    1.6e-05     0.0169
#          5   2.97e-06     0.0272
#          6   3.37e-06     0.0274
#          7   6.41e-07     0.0279
#          8      8e-07     0.0281
#          9   2.36e-06     0.0287
#         10   1.85e-08     0.0289
# done in 1.110 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 18.925 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -75.1      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 100        |
# | TimeElapsed     | 235        |
# | TimestepsSoFar  | 100000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0333     |
# | meankl          | 0.00807469 |
# | optimgain       | 0.00278825 |
# | surrgain        | 0.00278825 |
# --------------------------------
# ********** Iteration 2 ************
# sampling
# done in 95.244 seconds
# computegrad
# done in 0.258 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00133          0
#          1   0.000319    0.00499
#          2   8.07e-05     0.0104
#          3   5.21e-05     0.0149
#          4    8.4e-06     0.0156
#          5   1.48e-05     0.0216
#          6   9.83e-06     0.0224
#          7    3.9e-06     0.0243
#          8   3.96e-07      0.025
#          9   1.61e-06     0.0251
#         10   2.29e-07     0.0259
# done in 1.110 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 18.114 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -75.1      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 150        |
# | TimeElapsed     | 350        |
# | TimestepsSoFar  | 150000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0474     |
# | meankl          | 0.00845019 |
# | optimgain       | 0.00290931 |
# | surrgain        | 0.00290931 |
# --------------------------------
# ********** Iteration 3 ************
# sampling
# done in 94.150 seconds
# computegrad
# done in 0.264 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00115          0
#          1   0.000244    0.00437
#          2   5.25e-05    0.00885
#          3   6.87e-05     0.0116
#          4   4.59e-06     0.0128
#          5   1.62e-05     0.0157
#          6   1.49e-05     0.0172
#          7   3.53e-06     0.0189
#          8   2.84e-07     0.0204
#          9   3.43e-07     0.0204
#         10   4.66e-07     0.0206
# done in 1.022 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 20.014 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -74.9      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 200        |
# | TimeElapsed     | 467        |
# | TimestepsSoFar  | 200000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0412     |
# | meankl          | 0.00866125 |
# | optimgain       | 0.0024905  |
# | surrgain        | 0.0024905  |
# --------------------------------
# ********** Iteration 4 ************
# sampling
# done in 96.887 seconds
# computegrad
# done in 0.279 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000813          0
#          1    0.00037    0.00695
#          2    6.9e-05     0.0101
#          3    3.3e-05     0.0151
#          4   1.98e-05     0.0158
#          5   2.82e-05     0.0247
#          6   1.09e-05     0.0261
#          7   1.99e-06     0.0269
#          8   7.65e-07     0.0275
#          9   3.72e-06     0.0278
#         10   1.61e-06     0.0284
# done in 1.049 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 18.640 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -74.8      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 250        |
# | TimeElapsed     | 585        |
# | TimestepsSoFar  | 250000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0463     |
# | meankl          | 0.00808093 |
# | optimgain       | 0.00282049 |
# | surrgain        | 0.00282049 |
# --------------------------------
# ********** Iteration 5 ************
# sampling
# done in 97.047 seconds
# computegrad
# done in 0.254 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00057          0
#          1   0.000145    0.00349
#          2   5.19e-05    0.00744
#          3   4.52e-05    0.00876
#          4    7.5e-06     0.0104
#          5   2.69e-05     0.0158
#          6   9.41e-06     0.0175
#          7   4.24e-06     0.0197
#          8   2.51e-06     0.0205
#          9   3.05e-07     0.0206
#         10      5e-07     0.0211
# done in 1.033 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 18.500 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -74.4      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 300        |
# | TimeElapsed     | 703        |
# | TimestepsSoFar  | 300000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0404     |
# | meankl          | 0.00788473 |
# | optimgain       | 0.00194883 |
# | surrgain        | 0.00194883 |
# --------------------------------
# ********** Iteration 6 ************
# sampling
# done in 94.926 seconds
# computegrad
# done in 0.268 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00187          0
#          1   0.000346    0.00525
#          2   8.03e-05    0.00845
#          3   4.95e-05    0.00939
#          4   9.77e-06     0.0117
#          5   1.12e-05     0.0125
#          6   1.94e-05     0.0134
#          7   3.45e-06     0.0166
#          8   2.96e-06      0.018
#          9   6.19e-07     0.0182
#         10   7.77e-07     0.0184
# done in 1.280 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 19.919 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -74.2      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 350        |
# | TimeElapsed     | 821        |
# | TimestepsSoFar  | 350000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.036      |
# | meankl          | 0.00968525 |
# | optimgain       | 0.00296344 |
# | surrgain        | 0.00296344 |
# --------------------------------
# ********** Iteration 7 ************
# sampling
# done in 93.763 seconds
# computegrad
# done in 0.296 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00111          0
#          1    0.00038    0.00553
#          2   0.000147    0.00994
#          3   0.000108     0.0124
#          4   1.28e-05     0.0152
#          5   2.86e-05     0.0164
#          6   4.47e-05     0.0189
#          7   1.01e-05     0.0235
#          8   9.86e-06     0.0254
#          9   1.12e-06     0.0259
#         10   1.84e-06     0.0264
# done in 1.151 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 19.687 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.8      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 400        |
# | TimeElapsed     | 936        |
# | TimestepsSoFar  | 400000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0477     |
# | meankl          | 0.00822876 |
# | optimgain       | 0.00292824 |
# | surrgain        | 0.00292824 |
# --------------------------------
# ********** Iteration 8 ************
# sampling
# done in 95.078 seconds
# computegrad
# done in 0.339 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000757          0
#          1   0.000213     0.0058
#          2   8.35e-05    0.00799
#          3   7.27e-05     0.0101
#          4   1.21e-05     0.0119
#          5   1.51e-05     0.0135
#          6   2.72e-05     0.0168
#          7   7.04e-06     0.0187
#          8   1.01e-06     0.0202
#          9   4.14e-06     0.0205
#         10   1.43e-06     0.0214
# done in 1.126 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 18.393 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.7      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 450        |
# | TimeElapsed     | 1.05e+03   |
# | TimestepsSoFar  | 450000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0494     |
# | meankl          | 0.00861864 |
# | optimgain       | 0.00243444 |
# | surrgain        | 0.00243444 |
# --------------------------------
# ********** Iteration 9 ************
# sampling
# done in 97.776 seconds
# computegrad
# done in 0.256 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000948          0
#          1   0.000327    0.00729
#          2   9.08e-05     0.0105
#          3   9.96e-05     0.0136
#          4   1.64e-05     0.0151
#          5   2.42e-05     0.0162
#          6   4.68e-05     0.0197
#          7   3.01e-06     0.0226
#          8   3.42e-06     0.0232
#          9   2.89e-06     0.0235
#         10   1.79e-06     0.0241
# done in 1.270 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 18.923 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.4      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 500        |
# | TimeElapsed     | 1.17e+03   |
# | TimestepsSoFar  | 500000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.046      |
# | meankl          | 0.00867341 |
# | optimgain       | 0.00281473 |
# | surrgain        | 0.00281473 |
# --------------------------------
# ********** Iteration 10 ************
# sampling
# done in 95.168 seconds
# computegrad
# done in 0.254 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000827          0
#          1   0.000157    0.00445
#          2   0.000135    0.00806
#          3   5.46e-05       0.01
#          4   1.62e-05     0.0127
#          5   3.59e-05     0.0139
#          6    3.6e-05     0.0188
#          7   2.78e-06     0.0227
#          8   2.36e-06     0.0234
#          9   3.46e-06     0.0238
#         10   1.65e-06     0.0243
# done in 1.016 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 21.173 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.3      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 550        |
# | TimeElapsed     | 1.29e+03   |
# | TimestepsSoFar  | 550000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0122     |
# | meankl          | 0.00796115 |
# | optimgain       | 0.00243311 |
# | surrgain        | 0.00243311 |
# --------------------------------
# ********** Iteration 11 ************
# sampling
# done in 94.982 seconds
# computegrad
# done in 0.256 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00144          0
#          1   0.000221    0.00533
#          2   0.000202     0.0101
#          3   8.26e-05     0.0124
#          4      4e-05     0.0148
#          5   2.18e-05     0.0158
#          6    3.1e-05      0.019
#          7   1.21e-05     0.0222
#          8   1.22e-05     0.0235
#          9    2.9e-06     0.0243
#         10   1.66e-06     0.0249
# done in 0.996 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 17.820 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -72.9      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 600        |
# | TimeElapsed     | 1.41e+03   |
# | TimestepsSoFar  | 600000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0355     |
# | meankl          | 0.00827468 |
# | optimgain       | 0.00289391 |
# | surrgain        | 0.00289391 |
# --------------------------------
# ********** Iteration 12 ************
# sampling
# done in 95.266 seconds
# computegrad
# done in 0.257 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000838          0
#          1   0.000203    0.00443
#          2   0.000105    0.00659
#          3   7.08e-05    0.00828
#          4   3.14e-05     0.0114
#          5   2.68e-05      0.013
#          6   3.31e-05      0.015
#          7      8e-06     0.0214
#          8   6.22e-06     0.0228
#          9   3.26e-06     0.0233
#         10   1.11e-06     0.0237
# done in 1.196 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 19.848 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -72.9      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 650        |
# | TimeElapsed     | 1.52e+03   |
# | TimestepsSoFar  | 650000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0376     |
# | meankl          | 0.00776907 |
# | optimgain       | 0.0022005  |
# | surrgain        | 0.0022005  |
# --------------------------------
# ********** Iteration 13 ************
# sampling
# done in 97.296 seconds
# computegrad
# done in 0.278 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000607          0
#          1   0.000205    0.00398
#          2   0.000109    0.00689
#          3   4.49e-05    0.00839
#          4   1.61e-05     0.0101
#          5   1.54e-05     0.0109
#          6   1.66e-05     0.0122
#          7   1.19e-05     0.0147
#          8   1.15e-05      0.017
#          9   1.16e-06     0.0178
#         10    1.6e-06     0.0185
# done in 1.071 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 19.817 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -72.9      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 700        |
# | TimeElapsed     | 1.64e+03   |
# | TimestepsSoFar  | 700000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0311     |
# | meankl          | 0.008257   |
# | optimgain       | 0.00210791 |
# | surrgain        | 0.00210791 |
# --------------------------------
# ********** Iteration 14 ************
# sampling
# done in 96.874 seconds
# computegrad
# done in 0.261 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00295          0
#          1   0.000343     0.0053
#          2   0.000194     0.0093
#          3   5.26e-05     0.0115
#          4   1.21e-05     0.0132
#          5   1.11e-05     0.0139
#          6   1.01e-05     0.0145
#          7   9.22e-06     0.0154
#          8   3.53e-06     0.0195
#          9   1.13e-06     0.0198
#         10    8.1e-07     0.0201
# done in 1.019 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 18.078 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.2      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 750        |
# | TimeElapsed     | 1.76e+03   |
# | TimestepsSoFar  | 750000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0129     |
# | meankl          | 0.00919336 |
# | optimgain       | 0.00327488 |
# | surrgain        | 0.00327488 |
# --------------------------------
# ********** Iteration 15 ************
# sampling
# done in 93.620 seconds
# computegrad
# done in 0.241 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000579          0
#          1   0.000179    0.00482
#          2   4.61e-05    0.00798
#          3    2.8e-05     0.0101
#          4   4.82e-06     0.0107
#          5    1.3e-05      0.011
#          6   1.41e-05     0.0125
#          7   3.57e-06     0.0151
#          8   3.26e-06      0.016
#          9   1.23e-06     0.0164
#         10    2.7e-07     0.0167
# done in 1.194 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 19.302 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.1      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 800        |
# | TimeElapsed     | 1.88e+03   |
# | TimestepsSoFar  | 800000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0136     |
# | meankl          | 0.00879822 |
# | optimgain       | 0.00205498 |
# | surrgain        | 0.00205498 |
# --------------------------------
# ********** Iteration 16 ************
# sampling
# done in 95.593 seconds
# computegrad
# done in 0.244 seconds
# cg
#       iter residual norm  soln norm
#          0      0.001          0
#          1   0.000132    0.00421
#          2   0.000128    0.00619
#          3   2.58e-05    0.00898
#          4   1.66e-05     0.0102
#          5    1.2e-05     0.0109
#          6    1.4e-05     0.0141
#          7   1.37e-05     0.0164
#          8   3.26e-06     0.0178
#          9   1.25e-06     0.0183
#         10   1.66e-06     0.0191
# done in 1.089 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 18.410 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.2      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 850        |
# | TimeElapsed     | 1.99e+03   |
# | TimestepsSoFar  | 850000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0122     |
# | meankl          | 0.00870634 |
# | optimgain       | 0.00219769 |
# | surrgain        | 0.00219769 |
# --------------------------------
# ********** Iteration 17 ************
# sampling
# done in 95.521 seconds
# computegrad
# done in 0.302 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00224          0
#          1   0.000434     0.0062
#          2   0.000189    0.00946
#          3    5.6e-05     0.0115
#          4   2.25e-05     0.0134
#          5   1.41e-05      0.014
#          6   1.02e-05     0.0157
#          7   1.25e-05     0.0177
#          8   5.02e-06     0.0198
#          9   2.12e-06     0.0203
#         10    2.4e-06     0.0207
# done in 1.178 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 18.963 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.3      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 900        |
# | TimeElapsed     | 2.11e+03   |
# | TimestepsSoFar  | 900000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0192     |
# | meankl          | 0.00932733 |
# | optimgain       | 0.00315482 |
# | surrgain        | 0.00315482 |
# --------------------------------
# ********** Iteration 18 ************
# sampling
# done in 91.756 seconds
# computegrad
# done in 0.251 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00138          0
#          1   0.000262    0.00602
#          2   0.000142    0.00859
#          3   0.000106     0.0106
#          4   2.71e-05     0.0137
#          5   1.94e-05     0.0146
#          6   3.87e-05     0.0167
#          7   1.08e-05     0.0214
#          8   6.41e-06     0.0222
#          9   3.99e-06      0.023
#         10   3.24e-06     0.0239
# done in 0.957 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 19.341 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.1      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 950        |
# | TimeElapsed     | 2.22e+03   |
# | TimestepsSoFar  | 950000     |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.00189    |
# | meankl          | 0.00878546 |
# | optimgain       | 0.00287936 |
# | surrgain        | 0.00287936 |
# --------------------------------
# ********** Iteration 19 ************
# sampling
# done in 97.654 seconds
# computegrad
# done in 0.232 seconds
# cg
#       iter residual norm  soln norm
#          0   0.000356          0
#          1   0.000129    0.00411
#          2   5.84e-05    0.00635
#          3    6.6e-05    0.00809
#          4   1.37e-05    0.00976
#          5    1.3e-05     0.0104
#          6   2.32e-05     0.0123
#          7   9.01e-06     0.0156
#          8   9.14e-06     0.0178
#          9   1.96e-06     0.0187
#         10   8.41e-07      0.019
# done in 1.088 seconds
# Expected: 0.002 Actual: 0.002
# Stepsize OK!
# vf
# done in 20.402 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73        |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1000       |
# | TimeElapsed     | 2.34e+03   |
# | TimestepsSoFar  | 1000000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0176     |
# | meankl          | 0.00773812 |
# | optimgain       | 0.00184888 |
# | surrgain        | 0.00184888 |
# --------------------------------
# ********** Iteration 20 ************
# sampling
# done in 95.723 seconds
# computegrad
# done in 0.246 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00259          0
#          1   0.000426    0.00485
#          2   0.000127    0.00885
#          3   4.96e-05     0.0102
#          4    9.7e-06     0.0118
#          5   1.36e-05     0.0123
#          6   4.73e-06      0.013
#          7   1.17e-05     0.0142
#          8   7.32e-06     0.0156
#          9    1.5e-06     0.0163
#         10   1.45e-06     0.0167
# done in 1.108 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 19.956 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.2      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1050       |
# | TimeElapsed     | 2.46e+03   |
# | TimestepsSoFar  | 1050000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0125     |
# | meankl          | 0.00924864 |
# | optimgain       | 0.00299878 |
# | surrgain        | 0.00299878 |
# --------------------------------
# ********** Iteration 21 ************
# sampling
# done in 95.358 seconds
# computegrad
# done in 0.240 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00152          0
#          1   0.000281    0.00608
#          2   7.88e-05    0.00995
#          3   5.57e-05     0.0118
#          4   4.81e-06     0.0128
#          5   8.63e-06      0.013
#          6   8.39e-06     0.0138
#          7   1.05e-05     0.0154
#          8   4.72e-06     0.0166
#          9   1.15e-06     0.0175
#         10    6.1e-07     0.0178
# done in 1.049 seconds
# Expected: 0.003 Actual: 0.003
# Stepsize OK!
# vf
# done in 19.103 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.2      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1100       |
# | TimeElapsed     | 2.58e+03   |
# | TimestepsSoFar  | 1100000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0281     |
# | meankl          | 0.00894659 |
# | optimgain       | 0.00265899 |
# | surrgain        | 0.00265899 |
# --------------------------------
# ********** Iteration 22 ************
# sampling
# done in 94.253 seconds
# computegrad
# done in 0.274 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00462          0
#          1   0.000825    0.00723
#          2   0.000418     0.0125
#          3   7.01e-05     0.0159
#          4    2.8e-05     0.0177
#          5   1.89e-05     0.0184
#          6   1.24e-05     0.0192
#          7   1.16e-05     0.0203
#          8   1.51e-05     0.0219
#          9   1.89e-06     0.0228
#         10   2.24e-06     0.0236
# done in 1.179 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 19.536 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.2      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1150       |
# | TimeElapsed     | 2.69e+03   |
# | TimestepsSoFar  | 1150000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0446     |
# | meankl          | 0.00951417 |
# | optimgain       | 0.00421614 |
# | surrgain        | 0.00421614 |
# --------------------------------
# ********** Iteration 23 ************
# sampling
# done in 93.478 seconds
# computegrad
# done in 0.244 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00544          0
#          1    0.00106    0.00745
#          2   0.000322     0.0126
#          3   9.62e-05     0.0153
#          4   2.75e-05     0.0166
#          5   2.22e-05     0.0179
#          6   2.16e-05     0.0194
#          7   2.31e-05     0.0207
#          8   3.49e-06     0.0267
#          9   2.76e-06     0.0273
#         10    6.2e-06     0.0278
# done in 1.156 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 18.565 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -72.9      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1200       |
# | TimeElapsed     | 2.81e+03   |
# | TimestepsSoFar  | 1200000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.0789     |
# | meankl          | 0.00931746 |
# | optimgain       | 0.00434816 |
# | surrgain        | 0.00434816 |
# --------------------------------
# ********** Iteration 24 ************
# sampling
# done in 97.090 seconds
# computegrad
# done in 0.240 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0299          0
#          1    0.00343     0.0141
#          2    0.00124     0.0232
#          3   0.000364     0.0287
#          4   5.65e-05     0.0304
#          5   9.54e-05     0.0325
#          6    9.4e-05     0.0347
#          7   4.85e-05     0.0377
#          8   9.42e-05     0.0423
#          9   6.39e-06     0.0449
#         10   6.26e-06     0.0456
# done in 1.163 seconds
# Expected: 0.009 Actual: 0.009
# Stepsize OK!
# vf
# done in 19.582 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.1      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1250       |
# | TimeElapsed     | 2.93e+03   |
# | TimestepsSoFar  | 1250000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.151      |
# | meankl          | 0.00976995 |
# | optimgain       | 0.00873273 |
# | surrgain        | 0.00873273 |
# --------------------------------
# ********** Iteration 25 ************
# sampling
# done in 93.142 seconds
# computegrad
# done in 0.242 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0266          0
#          1    0.00197     0.0109
#          2    0.00123     0.0185
#          3   0.000172     0.0234
#          4   5.09e-05     0.0246
#          5   6.25e-05     0.0254
#          6   3.16e-05     0.0266
#          7   1.52e-05     0.0276
#          8   4.74e-05     0.0286
#          9   3.66e-06     0.0312
#         10   7.12e-06     0.0318
# done in 1.039 seconds
# Expected: 0.007 Actual: 0.007
# Stepsize OK!
# vf
# done in 18.624 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.1      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1300       |
# | TimeElapsed     | 3.04e+03   |
# | TimestepsSoFar  | 1300000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.32       |
# | meankl          | 0.00991037 |
# | optimgain       | 0.0071465  |
# | surrgain        | 0.0071465  |
# --------------------------------
# ********** Iteration 26 ************
# sampling
# done in 96.126 seconds
# computegrad
# done in 0.251 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0401          0
#          1    0.00229     0.0114
#          2    0.00179     0.0175
#          3   0.000382     0.0252
#          4   8.58e-05     0.0273
#          5   0.000139     0.0285
#          6   4.26e-05     0.0303
#          7   3.25e-05     0.0321
#          8   7.27e-05     0.0344
#          9   8.24e-06     0.0358
#         10   1.64e-05     0.0369
# done in 1.092 seconds
# Expected: 0.008 Actual: 0.008
# Stepsize OK!
# vf
# done in 21.002 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -72.9      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1350       |
# | TimeElapsed     | 3.16e+03   |
# | TimestepsSoFar  | 1350000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.502      |
# | meankl          | 0.0100102  |
# | optimgain       | 0.00809739 |
# | surrgain        | 0.00809739 |
# --------------------------------
# ********** Iteration 27 ************
# sampling
# done in 93.781 seconds
# computegrad
# done in 0.221 seconds
# cg
#       iter residual norm  soln norm
#          0      0.121          0
#          1    0.00551     0.0163
#          2    0.00331      0.024
#          3    0.00177     0.0321
#          4   0.000326      0.039
#          5   0.000573     0.0416
#          6   0.000311     0.0471
#          7   0.000244     0.0558
#          8   0.000256     0.0585
#          9   3.47e-05     0.0683
#         10   5.62e-05       0.07
# done in 1.059 seconds
# Expected: 0.013 Actual: 0.013
# Stepsize OK!
# vf
# done in 18.252 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73        |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1400       |
# | TimeElapsed     | 3.28e+03   |
# | TimestepsSoFar  | 1400000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.727      |
# | meankl          | 0.00973002 |
# | optimgain       | 0.0130267  |
# | surrgain        | 0.0130267  |
# --------------------------------
# ********** Iteration 28 ************
# sampling
# done in 93.547 seconds
# computegrad
# done in 0.273 seconds
# cg
#       iter residual norm  soln norm
#          0      0.209          0
#          1    0.00809     0.0181
#          2    0.00373     0.0231
#          3    0.00201     0.0303
#          4   0.000463     0.0381
#          5   0.000231     0.0393
#          6   0.000131     0.0428
#          7    0.00025     0.0452
#          8   0.000106     0.0472
#          9    0.00016     0.0544
#         10    2.7e-05     0.0559
# done in 1.241 seconds
# Expected: 0.015 Actual: 0.015
# Stepsize OK!
# vf
# done in 20.588 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -72.6      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1450       |
# | TimeElapsed     | 3.39e+03   |
# | TimestepsSoFar  | 1450000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.818      |
# | meankl          | 0.00995114 |
# | optimgain       | 0.014562   |
# | surrgain        | 0.014562   |
# --------------------------------
# ********** Iteration 29 ************
# sampling
# done in 95.923 seconds
# computegrad
# done in 0.301 seconds
# cg
#       iter residual norm  soln norm
#          0      0.122          0
#          1    0.00318     0.0113
#          2    0.00235     0.0148
#          3    0.00112      0.021
#          4   0.000425     0.0276
#          5   0.000287     0.0292
#          6   9.74e-05     0.0323
#          7   0.000269     0.0357
#          8   6.66e-05     0.0376
#          9   0.000269     0.0423
#         10   7.59e-05     0.0445
# done in 1.192 seconds
# Expected: 0.010 Actual: 0.010
# Stepsize OK!
# vf
# done in 19.024 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -72.9      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1500       |
# | TimeElapsed     | 3.51e+03   |
# | TimestepsSoFar  | 1500000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.876      |
# | meankl          | 0.00998133 |
# | optimgain       | 0.0100589  |
# | surrgain        | 0.0100589  |
# --------------------------------
# ********** Iteration 30 ************
# sampling
# done in 93.064 seconds
# computegrad
# done in 0.238 seconds
# cg
#       iter residual norm  soln norm
#          0       0.13          0
#          1    0.00307    0.00982
#          2    0.00147     0.0135
#          3   0.000755     0.0159
#          4    0.00032     0.0216
#          5   0.000395     0.0232
#          6   0.000119     0.0282
#          7   0.000392     0.0355
#          8   7.96e-05     0.0382
#          9   0.000562     0.0409
#         10   0.000157     0.0474
# done in 1.025 seconds
# Expected: 0.010 Actual: 0.010
# Stepsize OK!
# vf
# done in 19.658 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -72.9      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1550       |
# | TimeElapsed     | 3.63e+03   |
# | TimestepsSoFar  | 1550000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.881      |
# | meankl          | 0.00963226 |
# | optimgain       | 0.00955271 |
# | surrgain        | 0.00955271 |
# --------------------------------
# ********** Iteration 31 ************
# sampling
# done in 95.931 seconds
# computegrad
# done in 0.231 seconds
# cg
#       iter residual norm  soln norm
#          0      0.112          0
#          1    0.00485    0.00841
#          2      0.002     0.0106
#          3   0.000676     0.0142
#          4    0.00146      0.019
#          5   0.000212     0.0239
#          6   0.000144     0.0293
#          7   0.000232     0.0305
#          8   4.72e-05     0.0357
#          9   0.000259     0.0377
#         10   0.000201     0.0412
# done in 1.132 seconds
# Expected: 0.009 Actual: 0.009
# Stepsize OK!
# vf
# done in 19.715 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.2      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1600       |
# | TimeElapsed     | 3.74e+03   |
# | TimestepsSoFar  | 1600000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.889      |
# | meankl          | 0.00964821 |
# | optimgain       | 0.00876987 |
# | surrgain        | 0.00876987 |
# --------------------------------
# ********** Iteration 32 ************
# sampling
# done in 97.781 seconds
# computegrad
# done in 0.313 seconds
# cg
#       iter residual norm  soln norm
#          0      0.127          0
#          1    0.00309    0.00789
#          2    0.00142    0.00917
#          3    0.00109     0.0157
#          4    0.00162     0.0212
#          5   0.000337     0.0274
#          6    0.00018     0.0326
#          7   0.000197     0.0335
#          8   0.000126     0.0412
#          9   0.000203     0.0425
#         10   0.000601     0.0477
# done in 1.100 seconds
# Expected: 0.009 Actual: 0.009
# Stepsize OK!
# vf
# done in 19.073 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.4      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1650       |
# | TimeElapsed     | 3.86e+03   |
# | TimestepsSoFar  | 1650000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.902      |
# | meankl          | 0.00977378 |
# | optimgain       | 0.00869609 |
# | surrgain        | 0.00869609 |
# --------------------------------
# ********** Iteration 33 ************
# sampling
# done in 94.805 seconds
# computegrad
# done in 0.256 seconds
# cg
#       iter residual norm  soln norm
#          0      0.123          0
#          1    0.00195    0.00695
#          2    0.00132    0.00805
#          3    0.00107     0.0135
#          4    0.00162     0.0196
#          5   0.000175     0.0254
#          6   0.000302     0.0289
#          7   0.000125     0.0302
#          8   0.000129     0.0355
#          9   0.000134     0.0361
#         10   0.000301     0.0376
# done in 1.204 seconds
# Expected: 0.008 Actual: 0.008
# Stepsize OK!
# vf
# done in 19.981 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.3      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1700       |
# | TimeElapsed     | 3.98e+03   |
# | TimestepsSoFar  | 1700000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.914      |
# | meankl          | 0.00986237 |
# | optimgain       | 0.00792757 |
# | surrgain        | 0.00792757 |
# --------------------------------
# ********** Iteration 34 ************
# sampling
# done in 97.656 seconds
# computegrad
# done in 0.258 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0988          0
#          1    0.00198    0.00585
#          2    0.00169    0.00744
#          3   0.000837     0.0128
#          4    0.00115     0.0169
#          5   0.000409     0.0212
#          6   9.32e-05     0.0285
#          7    0.00042     0.0302
#          8   0.000211     0.0361
#          9   0.000176     0.0369
#         10   0.000426     0.0403
# done in 1.258 seconds
# Expected: 0.007 Actual: 0.007
# Stepsize OK!
# vf
# done in 19.095 seconds
# --------------------------------
# | EpLenMean       | 1e+03      |
# | EpRewMean       | -73.5      |
# | EpThisIter      | 50         |
# | EpisodesSoFar   | 1750       |
# | TimeElapsed     | 4.1e+03    |
# | TimestepsSoFar  | 1750000    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.917      |
# | meankl          | 0.0092221  |
# | optimgain       | 0.00699883 |
# | surrgain        | 0.00699883 |
# --------------------------------
# ********** Iteration 35 ************
# sampling
# done in 94.867 seconds
# computegrad
# done in 0.256 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0736          0
#          1    0.00535    0.00568
#          2    0.00179    0.00851
#          3   0.000565     0.0105
#          4    0.00083     0.0153
#          5   0.000567     0.0184
#          6   9.95e-05     0.0314
#          7   0.000376     0.0331
#          8   0.000141     0.0381
#          9   0.000389     0.0414
#         10    0.00018     0.0432
# done in 1.000 seconds
# Expected: 0.007 Actual: 0.007
# Stepsize OK!
# vf
# done in 18.655 seconds
# --------------------------------
# | EpLenMean       | 905        |
# | EpRewMean       | -64.9      |
# | EpThisIter      | 55         |
# | EpisodesSoFar   | 1805       |
# | TimeElapsed     | 4.22e+03   |
# | TimestepsSoFar  | 1799830    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.935      |
# | meankl          | 0.00942583 |
# | optimgain       | 0.00710085 |
# | surrgain        | 0.00710085 |
# --------------------------------
# ********** Iteration 36 ************
# sampling
# done in 98.787 seconds
# computegrad
# done in 0.251 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0376          0
#          1    0.00358    0.00472
#          2     0.0012    0.00712
#          3   0.000793     0.0105
#          4   0.000597     0.0146
#          5   0.000878     0.0209
#          6   0.000115     0.0252
#          7   0.000342     0.0278
#          8   0.000138     0.0305
#          9   0.000176     0.0362
#         10   9.74e-05     0.0369
# done in 1.132 seconds
# Expected: 0.006 Actual: 0.006
# Stepsize OK!
# vf
# done in 18.842 seconds
# --------------------------------
# | EpLenMean       | 731        |
# | EpRewMean       | -50.4      |
# | EpThisIter      | 68         |
# | EpisodesSoFar   | 1873       |
# | TimeElapsed     | 4.34e+03   |
# | TimestepsSoFar  | 1849605    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.974      |
# | meankl          | 0.00930992 |
# | optimgain       | 0.00567933 |
# | surrgain        | 0.00567933 |
# --------------------------------
# ********** Iteration 37 ************
# sampling
# done in 97.100 seconds
# computegrad
# done in 0.267 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0734          0
#          1    0.00675    0.00716
#          2   0.000813    0.00953
#          3   0.000927     0.0121
#          4   0.000445     0.0157
#          5   0.000295     0.0203
#          6   0.000163     0.0219
#          7   0.000157      0.026
#          8   0.000201     0.0278
#          9   8.93e-05     0.0317
#         10   0.000122     0.0323
# done in 1.127 seconds
# Expected: 0.008 Actual: 0.007
# Stepsize OK!
# vf
# done in 20.145 seconds
# --------------------------------
# | EpLenMean       | 656        |
# | EpRewMean       | -44.3      |
# | EpThisIter      | 76         |
# | EpisodesSoFar   | 1949       |
# | TimeElapsed     | 4.46e+03   |
# | TimestepsSoFar  | 1899608    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.988      |
# | meankl          | 0.00982629 |
# | optimgain       | 0.00712293 |
# | surrgain        | 0.00712293 |
# --------------------------------
# ********** Iteration 38 ************
# sampling
# done in 96.589 seconds
# computegrad
# done in 0.240 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0934          0
#          1    0.00593    0.00788
#          2    0.00209     0.0107
#          3   0.000783     0.0206
#          4    0.00052     0.0257
#          5   0.000208     0.0272
#          6   0.000168     0.0296
#          7   0.000555     0.0337
#          8   0.000112     0.0392
#          9   0.000241     0.0405
#         10   7.09e-05     0.0418
# done in 1.090 seconds
# Expected: 0.009 Actual: 0.008
# Stepsize OK!
# vf
# done in 19.299 seconds
# --------------------------------
# | EpLenMean       | 610        |
# | EpRewMean       | -40.8      |
# | EpThisIter      | 83         |
# | EpisodesSoFar   | 2032       |
# | TimeElapsed     | 4.57e+03   |
# | TimestepsSoFar  | 1949907    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.995      |
# | meankl          | 0.00965427 |
# | optimgain       | 0.00824468 |
# | surrgain        | 0.00824468 |
# --------------------------------
# ********** Iteration 39 ************
# sampling
# done in 96.766 seconds
# computegrad
# done in 0.241 seconds
# cg
#       iter residual norm  soln norm
#          0       0.16          0
#          1     0.0106     0.0107
#          2    0.00371     0.0142
#          3    0.00164      0.024
#          4    0.00132     0.0282
#          5   0.000297     0.0328
#          6    0.00033     0.0349
#          7   0.000418      0.037
#          8   0.000232     0.0503
#          9   0.000193      0.053
#         10   0.000155      0.054
# done in 1.164 seconds
# Expected: 0.011 Actual: 0.011
# Stepsize OK!
# vf
# done in 18.778 seconds
# --------------------------------
# | EpLenMean       | 562        |
# | EpRewMean       | -37        |
# | EpThisIter      | 89         |
# | EpisodesSoFar   | 2121       |
# | TimeElapsed     | 4.69e+03   |
# | TimestepsSoFar  | 1999450    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.998      |
# | meankl          | 0.00978929 |
# | optimgain       | 0.0105505  |
# | surrgain        | 0.0105505  |
# --------------------------------
# ********** Iteration 40 ************
# sampling
# done in 96.315 seconds
# computegrad
# done in 0.218 seconds
# cg
#       iter residual norm  soln norm
#          0      0.308          0
#          1     0.0158     0.0145
#          2     0.0101     0.0197
#          3    0.00348     0.0323
#          4    0.00262     0.0377
#          5   0.000535      0.046
#          6   0.000854     0.0483
#          7    0.00149     0.0556
#          8    0.00024      0.073
#          9    0.00123     0.0761
#         10   0.000483     0.0812
# done in 1.069 seconds
# Expected: 0.016 Actual: 0.014
# Stepsize OK!
# vf
# done in 19.596 seconds
# --------------------------------
# | EpLenMean       | 539        |
# | EpRewMean       | -35.2      |
# | EpThisIter      | 92         |
# | EpisodesSoFar   | 2213       |
# | TimeElapsed     | 4.81e+03   |
# | TimestepsSoFar  | 2049625    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.999      |
# | meankl          | 0.00951003 |
# | optimgain       | 0.0144692  |
# | surrgain        | 0.0144692  |
# --------------------------------
# ********** Iteration 41 ************
# sampling
# done in 97.878 seconds
# computegrad
# done in 0.255 seconds
# cg
#       iter residual norm  soln norm
#          0       0.45          0
#          1     0.0179     0.0172
#          2     0.0166     0.0238
#          3     0.0078     0.0406
#          4    0.00513     0.0515
#          5     0.0014     0.0625
#          6    0.00135     0.0673
#          7    0.00275     0.0745
#          8   0.000614     0.0937
#          9   0.000943      0.102
#         10     0.0006      0.114
# done in 1.000 seconds
# Expected: 0.019 Actual: 0.017
# Stepsize OK!
# vf
# done in 19.478 seconds
# --------------------------------
# | EpLenMean       | 506        |
# | EpRewMean       | -32.7      |
# | EpThisIter      | 98         |
# | EpisodesSoFar   | 2311       |
# | TimeElapsed     | 4.93e+03   |
# | TimestepsSoFar  | 2099753    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.999      |
# | meankl          | 0.00907011 |
# | optimgain       | 0.0173356  |
# | surrgain        | 0.0173356  |
# --------------------------------
# ********** Iteration 42 ************
# sampling
# done in 98.152 seconds
# computegrad
# done in 0.224 seconds
# cg
#       iter residual norm  soln norm
#          0      0.296          0
#          1     0.0127      0.014
#          2     0.0186     0.0229
#          3    0.00721     0.0409
#          4    0.00452     0.0548
#          5     0.0012     0.0627
#          6     0.0012     0.0675
#          7    0.00261      0.078
#          8   0.000597     0.0875
#          9   0.000894     0.0944
#         10    0.00258      0.102
# done in 1.069 seconds
# Expected: 0.017 Actual: 0.015
# Stepsize OK!
# vf
# done in 19.041 seconds
# --------------------------------
# | EpLenMean       | 484        |
# | EpRewMean       | -31.1      |
# | EpThisIter      | 102        |
# | EpisodesSoFar   | 2413       |
# | TimeElapsed     | 5.05e+03   |
# | TimestepsSoFar  | 2149772    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.999      |
# | meankl          | 0.00891198 |
# | optimgain       | 0.0154914  |
# | surrgain        | 0.0154914  |
# --------------------------------
# ********** Iteration 43 ************
# sampling
# done in 92.777 seconds
# computegrad
# done in 0.239 seconds
# cg
#       iter residual norm  soln norm
#          0      0.101          0
#          1    0.00678    0.00834
#          2    0.00737     0.0162
#          3    0.00486     0.0266
#          4    0.00214      0.035
#          5   0.000697     0.0399
#          6   0.000528     0.0434
#          7      0.001     0.0484
#          8    0.00023     0.0551
#          9   0.000352     0.0593
#         10   0.000465     0.0666
# done in 1.248 seconds
# Expected: 0.011 Actual: 0.010
# Stepsize OK!
# vf
# done in 18.862 seconds
# --------------------------------
# | EpLenMean       | 468        |
# | EpRewMean       | -29.8      |
# | EpThisIter      | 108        |
# | EpisodesSoFar   | 2521       |
# | TimeElapsed     | 5.16e+03   |
# | TimestepsSoFar  | 2199582    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.998      |
# | meankl          | 0.00909867 |
# | optimgain       | 0.00992749 |
# | surrgain        | 0.00992749 |
# --------------------------------
# ********** Iteration 44 ************
# sampling
# done in 99.167 seconds
# computegrad
# done in 0.277 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0563          0
#          1     0.0049    0.00621
#          2    0.00273     0.0139
#          3    0.00196     0.0191
#          4    0.00176     0.0239
#          5   0.000398     0.0285
#          6   0.000258     0.0306
#          7   0.000516     0.0337
#          8   0.000169     0.0391
#          9   0.000171     0.0418
#         10    0.00023     0.0476
# done in 1.109 seconds
# Expected: 0.008 Actual: 0.008
# Stepsize OK!
# vf
# done in 18.806 seconds
# --------------------------------
# | EpLenMean       | 468        |
# | EpRewMean       | -29.5      |
# | EpThisIter      | 109        |
# | EpisodesSoFar   | 2630       |
# | TimeElapsed     | 5.28e+03   |
# | TimestepsSoFar  | 2249899    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 0.999      |
# | meankl          | 0.00942094 |
# | optimgain       | 0.00751123 |
# | surrgain        | 0.00751123 |
# --------------------------------
# ********** Iteration 45 ************
# sampling
# done in 99.990 seconds
# computegrad
# done in 0.225 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0439          0
#          1    0.00559    0.00561
#          2    0.00339     0.0131
#          3    0.00157     0.0167
#          4    0.00123     0.0208
#          5   0.000304     0.0251
# ...
#          6    0.00116     0.0284
#          7   0.000359     0.0373
#          8   0.000303     0.0408
#          9   0.000309     0.0458
#         10   0.000145     0.0483
# done in 1.079 seconds
# Expected: 0.007 Actual: 0.006
# Stepsize OK!
# vf
# done in 20.095 seconds
# --------------------------------
# | EpLenMean       | 345        |
# | EpRewMean       | -22        |
# | EpThisIter      | 143        |
# | EpisodesSoFar   | 4181       |
# | TimeElapsed     | 6.75e+03   |
# | TimestepsSoFar  | 2849817    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 1          |
# | meankl          | 0.00897817 |
# | optimgain       | 0.00637723 |
# | surrgain        | 0.00637723 |
# --------------------------------
# ********** Iteration 57 ************
# sampling
# done in 97.486 seconds
# computegrad
# done in 0.260 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0305          0
#          1    0.00744      0.005
#          2    0.00618    0.00975
#          3    0.00331     0.0161
#          4    0.00179     0.0242
#          5   0.000765     0.0298
#          6   0.000812     0.0335
#          7    0.00127     0.0415
#          8    0.00022     0.0481
#          9   0.000556     0.0539
#         10   0.000265     0.0577
# done in 1.183 seconds
# Expected: 0.008 Actual: 0.008
# Stepsize OK!
# vf
# done in 20.456 seconds
# --------------------------------
# | EpLenMean       | 349        |
# | EpRewMean       | -22.3      |
# | EpThisIter      | 146        |
# | EpisodesSoFar   | 4327       |
# | TimeElapsed     | 6.87e+03   |
# | TimestepsSoFar  | 2899767    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 1          |
# | meankl          | 0.009037   |
# | optimgain       | 0.00786151 |
# | surrgain        | 0.00786151 |
# --------------------------------
# ********** Iteration 58 ************
# sampling
# done in 96.234 seconds
# computegrad
# done in 0.300 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0461          0
#          1    0.00591    0.00543
#          2    0.00407    0.00794
#          3    0.00238     0.0132
#          4    0.00195     0.0221
#          5     0.0014     0.0308
#          6     0.0023     0.0462
#          7    0.00103       0.06
#          8   0.000321     0.0652
#          9   0.000539     0.0694
#         10   0.000614     0.0738
# done in 1.335 seconds
# Expected: 0.008 Actual: 0.008
# Stepsize OK!
# vf
# done in 19.096 seconds
# --------------------------------
# | EpLenMean       | 353        |
# | EpRewMean       | -22.6      |
# | EpThisIter      | 144        |
# | EpisodesSoFar   | 4471       |
# | TimeElapsed     | 6.99e+03   |
# | TimestepsSoFar  | 2949826    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 1          |
# | meankl          | 0.00821144 |
# | optimgain       | 0.00830507 |
# | surrgain        | 0.00830507 |
# --------------------------------
# ********** Iteration 59 ************
# sampling
# done in 97.222 seconds
# computegrad
# done in 0.250 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0523          0
#          1    0.00676    0.00557
#          2    0.00538    0.00878
#          3    0.00191     0.0147
#          4    0.00158     0.0221
#          5   0.000646     0.0274
#          6    0.00143     0.0336
#          7   0.000801     0.0462
#          8   0.000222     0.0502
#          9    0.00042     0.0541
#         10   0.000395     0.0586
# done in 1.172 seconds
# Expected: 0.008 Actual: 0.007
# Stepsize OK!
# vf
# done in 20.028 seconds
# --------------------------------
# | EpLenMean       | 350        |
# | EpRewMean       | -22.4      |
# | EpThisIter      | 145        |
# | EpisodesSoFar   | 4616       |
# | TimeElapsed     | 7.11e+03   |
# | TimestepsSoFar  | 2999807    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 1          |
# | meankl          | 0.00887487 |
# | optimgain       | 0.00749262 |
# | surrgain        | 0.00749262 |
# --------------------------------
# ********** Iteration 60 ************
# sampling
# done in 94.637 seconds
# computegrad
# done in 0.250 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0408          0
#          1     0.0035    0.00476
#          2    0.00269    0.00612
#          3    0.00137     0.0184
#          4   0.000689     0.0231
#          5    0.00105     0.0283
#          6   0.000565     0.0405
#          7   0.000361     0.0448
#          8   0.000506     0.0491
#          9   0.000151     0.0554
#         10    0.00014      0.057
# done in 1.101 seconds
# Expected: 0.007 Actual: 0.007
# Stepsize OK!
# vf
# done in 19.092 seconds
# --------------------------------
# | EpLenMean       | 344        |
# | EpRewMean       | -21.9      |
# | EpThisIter      | 146        |
# | EpisodesSoFar   | 4762       |
# | TimeElapsed     | 7.22e+03   |
# | TimestepsSoFar  | 3049931    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 1          |
# | meankl          | 0.00860737 |
# | optimgain       | 0.00662361 |
# | surrgain        | 0.00662361 |
# --------------------------------
# ********** Iteration 61 ************
# sampling
# done in 97.820 seconds
# computegrad
# done in 0.251 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0054          0
#          1    0.00241    0.00459
#          2   0.000918     0.0069
#          3    0.00177     0.0101
#          4   0.000664     0.0125
#          5   0.000262     0.0156
#          6    0.00042     0.0188
#          7   0.000452     0.0274
#          8   7.37e-05     0.0315
#          9    0.00013     0.0329
#         10   7.09e-05     0.0377
# done in 1.079 seconds
# Expected: 0.004 Actual: 0.004
# Stepsize OK!
# vf
# done in 18.951 seconds
# --------------------------------
# | EpLenMean       | 346        |
# | EpRewMean       | -22.1      |
# | EpThisIter      | 144        |
# | EpisodesSoFar   | 4906       |
# | TimeElapsed     | 7.34e+03   |
# | TimestepsSoFar  | 3099666    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 1          |
# | meankl          | 0.00860339 |
# | optimgain       | 0.00442198 |
# | surrgain        | 0.00442198 |
# --------------------------------
# ********** Iteration 62 ************
# sampling
# done in 97.950 seconds
# computegrad
# done in 0.223 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00973          0
#          1    0.00305     0.0028
#          2    0.00253    0.00606
#          3    0.00203     0.0106
#          4   0.000245      0.015
#          5   0.000495     0.0173
#          6   0.000308     0.0243
#          7   0.000141     0.0269
#          8   0.000231     0.0306
#          9   0.000132     0.0336
#         10   0.000132      0.036
# done in 1.100 seconds
# Expected: 0.005 Actual: 0.005
# Stepsize OK!
# vf
# done in 18.385 seconds
# --------------------------------
# | EpLenMean       | 339        |
# | EpRewMean       | -21.6      |
# | EpThisIter      | 144        |
# | EpisodesSoFar   | 5050       |
# | TimeElapsed     | 7.46e+03   |
# | TimestepsSoFar  | 3149783    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 1          |
# | meankl          | 0.00883189 |
# | optimgain       | 0.00450131 |
# | surrgain        | 0.00450131 |
# --------------------------------
# ********** Iteration 63 ************
# sampling
# done in 94.642 seconds
# computegrad
# done in 0.289 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0134          0
#          1     0.0035    0.00333
#          2    0.00364     0.0064
#          3    0.00143     0.0104
#          4    0.00124     0.0192
#          5   0.000597     0.0243
#          6    0.00129     0.0345
#          7    0.00033     0.0447
#          8   0.000468      0.048
#          9   0.000364     0.0593
#         10    0.00026     0.0617
# done in 0.992 seconds
# Expected: 0.006 Actual: 0.006
# Stepsize OK!
# vf
# done in 19.356 seconds
# --------------------------------
# | EpLenMean       | 346        |
# | EpRewMean       | -22.1      |
# | EpThisIter      | 144        |
# | EpisodesSoFar   | 5194       |
# | TimeElapsed     | 7.58e+03   |
# | TimestepsSoFar  | 3199974    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 1          |
# | meankl          | 0.00767556 |
# | optimgain       | 0.005554   |
# | surrgain        | 0.005554   |
# --------------------------------
# ********** Iteration 64 ************
# sampling
# done in 97.510 seconds
# computegrad
# done in 0.238 seconds
# cg
#       iter residual norm  soln norm
#          0    0.00287          0
#          1    0.00242    0.00458
#          2    0.00148     0.0065
#          3    0.00137      0.013
#          4   0.000924     0.0215
#          5   0.000959     0.0245
#          6    0.00107     0.0314
#          7   0.000211     0.0394
#          8   9.38e-05     0.0409
#          9   0.000253      0.047
#         10   0.000121     0.0496
# done in 1.173 seconds
# Expected: 0.005 Actual: 0.005
# Stepsize OK!
# vf
# done in 19.520 seconds
# --------------------------------
# | EpLenMean       | 349        |
# | EpRewMean       | -22.3      |
# | EpThisIter      | 145        |
# | EpisodesSoFar   | 5339       |
# | TimeElapsed     | 7.7e+03    |
# | TimestepsSoFar  | 3249967    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 1          |
# | meankl          | 0.00791567 |
# | optimgain       | 0.00476829 |
# | surrgain        | 0.00476829 |
# --------------------------------
# ********** Iteration 65 ************
# sampling
# done in 99.816 seconds
# computegrad
# done in 0.256 seconds
# cg
#       iter residual norm  soln norm
#          0      0.031          0
#          1    0.00156    0.00329
#          2   0.000912    0.00609
#          3    0.00139     0.0108
#          4    0.00043     0.0135
#          5   0.000365      0.016
#          6   0.000863     0.0294
#          7   0.000159     0.0361
#          8   0.000259     0.0399
#          9   0.000382     0.0426
#         10   6.91e-05     0.0437
# done in 1.119 seconds
# Expected: 0.005 Actual: 0.005
# Stepsize OK!
# vf
# done in 18.902 seconds
# --------------------------------
# | EpLenMean       | 331        |
# | EpRewMean       | -21        |
# | EpThisIter      | 146        |
# | EpisodesSoFar   | 5485       |
# | TimeElapsed     | 7.82e+03   |
# | TimestepsSoFar  | 3299725    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 1          |
# | meankl          | 0.00891377 |
# | optimgain       | 0.0049844  |
# | surrgain        | 0.0049844  |
# --------------------------------
# ********** Iteration 66 ************
# sampling
# done in 97.787 seconds
# computegrad
# done in 0.223 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0052          0
#          1    0.00229    0.00325
#          2    0.00263    0.00843
#          3    0.00273     0.0151
#          4   0.000432     0.0173
#          5    0.00099     0.0234
#          6   0.000289     0.0335
#          7   0.000197     0.0354
#          8   0.000388     0.0421
#          9   0.000117     0.0461
#         10   0.000234     0.0488
# done in 1.177 seconds
# Expected: 0.005 Actual: 0.005
# Stepsize OK!
# vf
# done in 19.494 seconds
# --------------------------------
# | EpLenMean       | 344        |
# | EpRewMean       | -22        |
# | EpThisIter      | 148        |
# | EpisodesSoFar   | 5633       |
# | TimeElapsed     | 7.94e+03   |
# | TimestepsSoFar  | 3349908    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 1          |
# | meankl          | 0.00830614 |
# | optimgain       | 0.00493345 |
# | surrgain        | 0.00493345 |
# --------------------------------
# ********** Iteration 67 ************
# sampling
# done in 94.368 seconds
# computegrad
# done in 0.233 seconds
# cg
#       iter residual norm  soln norm
#          0     0.0367          0
#          1     0.0102     0.0045
#          2    0.00201     0.0104
#          3    0.00116     0.0115
#          4    0.00143     0.0184
#          5   0.000537     0.0234
#          6    0.00116     0.0318
#          7   0.000338     0.0415
#          8   0.000503     0.0453
#          9   0.000256     0.0555
#         10   0.000194     0.0561
# done in 1.056 seconds
# Expected: 0.007 Actual: 0.006
# Stepsize OK!
# vf
# done in 19.372 seconds
# --------------------------------
# | EpLenMean       | 350        |
# | EpRewMean       | -22.4      |
# | EpThisIter      | 144        |
# | EpisodesSoFar   | 5777       |
# | TimeElapsed     | 8.15e+03   |
# | TimestepsSoFar  | 3399933    |
# | entloss         | 0.0        |
# | entropy         | 7.09393    |
# | ev_tdlam_before | 1          |
# | meankl          | 0.00845028 |
# | optimgain       | 0.00635471 |
# | surrgain        | 0.00635471 |
# --------------------------------
# ********** Iteration 68 ************
# sampling
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5b13a18b9217> in <module>()
# ----> 1 agn.learn()
#
# /home/cc/notebook/final_result/robo2/new_model/base_line_model/TRPO_agent.py in learn(self)
#     229
#     230             with self.timed("sampling"):
# --> 231                 seg = seg_gen.__next__()
#     232
#     233             add_vtarg_and_adv(seg, self.gamma, self.lam)
#
# /home/cc/notebook/final_result/robo2/new_model/base_line_model/TRPO_agent.py in traj_segment_generator(pi, env, horizon, stochastic)
#      35     while True:
#      36         prevac = ac
# ---> 37         ac, vpred = pi.act(stochastic, ob)
#      38         # Slight weirdness here because we need value function at time T
#      39         # before returning segment [0, T-1] so we get the correct
#
# /home/cc/notebook/final_result/robo2/new_model/base_line_model/mlp.py in act(self, stochastic, ob)
#      53
#      54     def act(self, stochastic, ob):
# ---> 55         ac1, vpred1 =  self._act(stochastic, ob[None])
#      56         return ac1[0], vpred1[0]
#      57     def get_variables(self):
#
# /home/cc/aibaseline/baselines/baselines/common/tf_util.py in __call__(self, *args, **kwargs)
#     400         for inpt in self.givens:
#     401             feed_dict[inpt] = feed_dict.get(inpt, self.givens[inpt])
# --> 402         results = get_session().run(self.outputs_update, feed_dict=feed_dict)[:-1]
#     403         if self.check_nan:
#     404             if any(np.isnan(r).any() for r in results):
#
# /home/cc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/cc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# /home/cc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# /home/cc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# /home/cc/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
env2.result_plot()
